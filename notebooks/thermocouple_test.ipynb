# %%
# %load_ext autoreload
# %autoreload 2

import sys
import time
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
print(f"Project root added to sys.path: {project_root}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project root added to sys.path: c:\Users\au584144\Repos\lab-controller

# %%
from src.devices.thermocouple import Thermocouple

thermo = Thermocouple(vendor_id=0x2177, product_id=0x0004)

if thermo.connect():
    try:
        for i in range(10):
            temp = thermo.get_temperature()
            if temp is None:
                print("No reading returned.")
            else:
                print(f"Current temperature: {temp:.2f} °C")
            time.sleep(1)
    finally:
        thermo.disconnect()
else:
    print("Thermocouple failed to connect.")
# Out:
# Thermocouple connected
# Current temperature: 21.74 °C
# Current temperature: 21.74 °C
# Current temperature: 21.74 °C
# Current temperature: 21.75 °C
# Current temperature: 21.75 °C
# Current temperature: 21.76 °C
# Current temperature: 21.75 °C
# Current temperature: 21.75 °C
# Current temperature: 21.72 °C
# Current temperature: 21.72 °C
# Thermocouple disconnected
