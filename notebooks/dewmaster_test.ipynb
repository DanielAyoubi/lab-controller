# %%
# %load_ext autoreload
# %autoreload 2

import sys
import time
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
print(f"Project root added to sys.path: {project_root}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project root added to sys.path: c:\Users\au584144\Repos\lab-controller

# %%
from src.devices.dewmaster import DewMaster

# %%
dewmaster = DewMaster(port="COM9", baudrate=9600)

# %%
data = dewmaster.compute_relative_humidity(-4.5, 18.44)
print(data)
dewmaster.disconnect()
# Out:
# 20.69174376797971
