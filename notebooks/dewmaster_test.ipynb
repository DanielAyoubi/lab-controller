# %%
# %load_ext autoreload
# %autoreload 2

import sys
import time
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
print(f"Project root added to sys.path: {project_root}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project root added to sys.path: c:\Users\au584144\Repos\lab-controller

# %%
from src.devices.dewmaster import DewMaster

# %%
dewmaster = DewMaster(port="COM3", baudrate=9600)

if dewmaster.connect():
    try:
        while True:
            data = dewmaster.poll()
            if data:
                print(data)
            time.sleep(1)
    except KeyboardInterrupt:
        dewmaster.disconnect()
    finally:
        dewmaster.disconnect()
# Out:
# {'dew_point': -2.5, 'ambient_temp': 23.5}
# {'dew_point': -2.5, 'ambient_temp': 23.5}
# Disconnected DewMaster.
