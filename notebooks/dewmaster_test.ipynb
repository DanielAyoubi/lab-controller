# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
print(f"Project root added to sys.path: {project_root}")
# Out:
# Project root added to sys.path: c:\Users\au584144\Repos\lab-controller

# %%
import time
from src.devices.dewmaster import DewMaster
dewmaster = DewMaster(port="COM3", baudrate=19200)
dewmaster.connect()

for i in range(5):
    data = dewmaster.get_readings()
    print(data)
    time.sleep(1)
dewmaster.disconnect()
# Out:
# {'dewpoint_temp': -7.6, 'ambient_temp': 24.0, 'relative_humidity_device': 11.5, 'relative_humidity_calculated': 11.613904810725533}
# {'dewpoint_temp': -7.5, 'ambient_temp': 24.0, 'relative_humidity_device': 11.6, 'relative_humidity_calculated': 11.703962049202836}
# {'dewpoint_temp': -7.0, 'ambient_temp': 24.0, 'relative_humidity_device': 12.1, 'relative_humidity_calculated': 12.16363786765434}
# {'dewpoint_temp': -6.7, 'ambient_temp': 24.0, 'relative_humidity_device': 12.4, 'relative_humidity_calculated': 12.447090547707594}
# {'dewpoint_temp': -6.7, 'ambient_temp': 24.0, 'relative_humidity_device': 12.4, 'relative_humidity_calculated': 12.447090547707594}
# Disconnected DewMaster.

# %%
data = dewmaster.compute_relative_humidity(-4.5, 18.44)
print(data)
dewmaster.disconnect()
# Out:
# 20.69174376797971
